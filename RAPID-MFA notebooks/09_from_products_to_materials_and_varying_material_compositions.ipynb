# %% [markdown]
# # RAPID-MFA-9: Switching from products/services to materials with changing material compositions
#
# ## Descriptions
#
# This Dynamic MFA model makes the switch from modeling the flows and stocks of a __product (in numbers of units)__ or a __service (in appropriate units of service, e.g. m<sup>2</sup> of floor area, GW of electricity etc.)__ to the flows and stocks of a __material (in mass)__ contained in that product or service.
#
# This model goes by many names:
# - The [Demand-driven model](https://doi.org/10.1111/jiec.12284)
# - Services-products-materials cascade
# - [Müller 2006](https://doi.org/10.1016/j.ecolecon.2005.09.025)-style model (perhaps the one that introduced it in its common form)
# - [Multi-layer dynamic model](https://doi.org/10.1111/jiec.13023) depicting products, materials, and so on.
# - Stocks-flows-services nexus model
# - etc.
#
# It's built of __two daisy-chained dynamic MFA models:__ one for the product/service layer, and one for the materials layer. The **conversion** uses **_material intensities_** of mass per one unit of product or service provisioning.

# %% [markdown]
# <svg width="1081" height="321" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" overflow="hidden">
#     <g>
#         <rect x="0" y="0" width="1081" height="320.667" fill="#FFFFFF" />
#         <path d="M426 78.4186 426 78.4216C426 79.2492 425.328 79.9201 424.5 79.9201 423.672 79.9201 423 79.2492 423 78.4216L423 78.4186C423 77.591 423.672 76.9202 424.5 76.9202 425.328 76.9202 426 77.591 426 78.4186ZM426 84.4154 426 84.4184C426 85.246 425.328 85.9168 424.5 85.9168 423.672 85.9168 423 85.246 423 84.4184L423 84.4154C423 83.5878 423.672 82.9169 424.5 82.9169 425.328 82.9169 426 83.5878 426 84.4154ZM426 90.4122 426 90.4152C426 91.2427 425.328 91.9136 424.5 91.9136 423.672 91.9136 423 91.2427 423 90.4152L423 90.4122C423 89.5846 423.672 88.9137 424.5 88.9137 425.328 88.9137 426 89.5846 426 90.4122ZM426 96.4089 426 96.4119C426 97.2395 425.328 97.9104 424.5 97.9104 423.672 97.9104 423 97.2395 423 96.4119L423 96.4089C423 95.5814 423.672 94.9105 424.5 94.9105 425.328 94.9105 426 95.5814 426 96.4089ZM426 102.406 426 102.409C426 103.236 425.328 103.907 424.5 103.907 423.672 103.907 423 103.236 423 102.409L423 102.406C423 101.578 423.672 100.907 424.5 100.907 425.328 100.907 426 101.578 426 102.406ZM426 108.402 426 108.405C426 109.233 425.328 109.904 424.5 109.904 423.672 109.904 423 109.233 423 108.405L423 108.402C423 107.575 423.672 106.904 424.5 106.904 425.328 106.904 426 107.575 426 108.402ZM426 114.399 426 114.402C426 115.23 425.329 115.901 424.5 115.901 423.672 115.901 423 115.23 423 114.402L423 114.399C423 113.572 423.672 112.901 424.5 112.901 425.329 112.901 426 113.572 426 114.399ZM426 120.396 426 120.399C426 121.227 425.329 121.897 424.5 121.897 423.672 121.897 423 121.227 423 120.399L423 120.396C423 119.568 423.672 118.898 424.5 118.898 425.329 118.898 426 119.568 426 120.396ZM426 126.393 426 126.396C426 127.223 425.329 127.894 424.5 127.894 423.672 127.894 423 127.223 423 126.396L423 126.393C423 125.565 423.672 124.894 424.5 124.894 425.329 124.894 426 125.565 426 126.393ZM426 132.39 426 132.393C426 133.22 425.329 133.891 424.5 133.891 423.672 133.891 423 133.22 423 132.393L423 132.39C423 131.562 423.672 130.891 424.5 130.891 425.329 130.891 426 131.562 426 132.39Z
687 10.9887 858.515 10.9887ZM864.518 10.9887 864.521 10.9887C865.349 10.9887 866.021 11.6596 866.021 12.4872 866.021 13.3147 865.349 13.9856 864.521 13.9856L864.518 13.9856C863.69 13.9856 863.018 13.3147 863.018 12.4872 863.018 11.6596 863.69 10.9887 864.518 10.9887ZM864.854 7.99184 873.854 12.4872 864.854 16.9825Z" fill="#7F7F7F" />
#         <text font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 882.903 96)">Material or product flows</text>
#         <text font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 882.903 18)">Information “flows”</text>
#         <rect x="507" y="15.9834" width="141" height="98.8973" fill="#C58D01" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 547.419 49)">Stock of</text>
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 533.919 72)">products or</text>
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 547.586 94)">services</text>
#         <path d="M641 161.332 656.25 130.864 746.75 130.864 762 161.332 746.75 191.801 656.25 191.801Z" fill="#C32D2E" fill-rule="evenodd" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 672.071 156)">Survival</text>
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 680.404 179)">curve</text>
#         <path d="M450 161.332 467.545 130.864 585.455 130.864 603 161.332 585.455 191.801 467.545 191.801Z" fill="#C32D2E" fill-rule="evenodd" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 494.635 156)">Material</text>
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 488.049 179)">intensities</text>
#         <rect x="507" y="219.772" width="141" height="98.8973" fill="#3891A7" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 547.419 263)">Stock of</text>
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 542.419 286)">materials</text>
#         <path d="M384 48.2 480.5 48.2 480.5 35.9627 505 60.4372 480.5 84.9118 480.5 72.6746 384 72.6746Z" fill="#C58D01" fill-rule="evenodd" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 411.485 66)">Inflows</text>
#         <path d="M652 48.2 748.5 48.2 748.5 35.9627 773 60.4372 748.5 84.9118 748.5 72.6746 652 72.6746Z" fill="#C58D01" fill-rule="evenodd" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 672.817 66)">Outflows</text>
#         <path d="M384 263.976 480.5 263.976 480.5 251.739 505 276.213 480.5 300.688 480.5 288.451 384 288.451Z" fill="#3891A7" fill-rule="evenodd" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 411.485 281)">Inflows</text>
#         <path d="M652 263.976 748.5 263.976 748.5 251.739 773 276.213 748.5 300.688 748.5 288.451 652 288.451Z" fill="#3891A7" fill-rule="evenodd" />
#         <text fill="#FFFFFF" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 672.817 281)">Outflows</text>
#         <path d="M824 83.4134 860 83.4134 860 74.9222 877 91.9046 860 108.887 860 100.396 824 100.396Z" fill="#7F7F7F" fill-rule="evenodd" />
#         <path d="M424.5 160.334 452.211 160.334" stroke="#000000" stroke-width="3" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" stroke-dasharray="0 6" fill="none" fill-rule="evenodd" />
#         <path d="M457 25.4736C457 22.4392 459.462 19.9793 462.5 19.9793L512.5 19.9793C515.538 19.9793 518 22.4392 518 25.4736L518 47.4506C518 50.4851 515.538 52.945 512.5 52.945L462.5 52.945C459.462 52.945 457 50.4851 457 47.4506Z" stroke="#FEB80A" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <path d="M405 149.844C405 147.086 407.239 144.85 410 144.85L438 144.85C440.761 144.85 443 147.086 443 149.844L443 169.824C443 172.582 440.761 174.818 438 174.818L410 174.818C407.239 174.818 405 172.582 405 169.824Z" stroke="#C32D2E" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <path d="M337 34.9637 455.695 34.9638" stroke="#FEB80A" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 27.6762 40)">(This example is a stock driven model for</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 45.5962 63)">the products layer.</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 190.93 63)">This</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 225.096 63)">information</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 37.7628 85)">directionality is flipped if the products</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 67.1762 108)">layer are a flow</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 182.176 108)">-</text>
#         <text fill="#C58D01" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 187.843 108)">driven model)</text>
#         <path d="M823 46.9512 831.5 29.9689 867.5 29.9689 876 46.9512 867.5 63.9336 831.5 63.9336Z" fill="#7F7F7F" fill-rule="evenodd" />
#         <text font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 882.903 54)">Data inputs</text>
#         <rect x="4" y="175.817" width="347" height="118.877" stroke="#C32D2E" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" />
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 13.6346 207)">The switch from products to materials must</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 18.3813 230)">be done on the inflows to enable changing</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 29.6346 252)">material intensities, so the materials</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 49.7146 275)">layer</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="700" font-size="18.6473" transform="matrix(1 0 0 0.998963 90.7146 275)">must</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 132.048 275)">be a flow</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 200.381 275)">-</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 206.048 275)">driven model</text>
#         <path d="M242 159.834 405.229 159.834" stroke="#C32D2E" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <path d="M242 160.833 242 174.103" stroke="#C32D2E" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <path d="M665 142.019C665 136.962 669.104 132.862 674.167 132.862L730.833 132.862C735.896 132.862 740 136.962 740 142.019L740 178.648C740 183.705 735.896 187.805 730.833 187.805L674.167 187.805C669.104 187.805 665 183.705 665 178.648Z" stroke="#E17B7C" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <path d="M740 177.815 819.37 177.815" stroke="#E17B7C" stroke-width="4" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd" />
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 826.564 183)">(Assuming that materials last</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 824.73 206)">in use as long as the</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 978.897 206)">products</text>
#         <text fill="#C32D2E" font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 832.564 228)">they’re in. Can be changed)</text>
#         <rect x="824" y="114.881" width="53" height="34.9637" fill="#7F7F7F" />
#         <text font-family="Calibri Light,Calibri Light_MSFontService,sans-serif" font-weight="300" font-size="18.6473" transform="matrix(1 0 0 0.998963 882.903 139)">Material or product stocks</text>
#     </g>
# </svg>

# %% [markdown]
# ### The importance of correctly accounting for material intensities that change over time
#
# If _material intensities_ change over time, the stocks and outflows of the materials layer become composed of mixed cohorts with varying material compositions. The materials-layer MFA model __must be a flow driven model__ to ensure that if material intensities vary over time then the materials-level stocks and outflows are correct, accounting for the varying material intensities of each cohort within them. This means that the switch from products to materials is done through the inflows of both layers:
#
# $
# \textcolor{#2A8596}{\text{material inflows}(t)[mass]} = \textcolor{#C58D01}{\text{product inflows}(t)[units]} \times \textcolor{#C32D2E}{\text{material intensities}(t)[\frac{mass}{unit}]}
# $
#
# ### Material stock productivity
#
# _Material stock productivity_ is a metric or indicator of the service provisioning provided by each unit of material stock. Higher productivity idicates a more efficient system.
#
# $\text{material stock productivity}(t) = \frac{\text{service provision}(t)}{\text{material stock}(t)}$
#
# The end of this notebook shows how the change in newer inflows' material compositions **gradually** affects the _material stock productivity_ of service provisioning.
#
# ### Notes
#
# 1. The example used in this notebook showcases why the switch must be done through the inflows: _material intensities_ have a fixed value for the first ten timeframes (the years 2015-2025) and then start to decline. This is a case of _improving technology / lightweighting_: new product inflows use less and less materials per unit of service.
#
# 1. The materials layer should remain a _flow driven model_ for the reasons described above, but the products layer can be modeled by either a _stock driven model_ as in this example, or by a _flow driven model_ by simply replacing the relevant code cell.
#
# 1. This daisy-chained model can be extended to further layers beyond the products layer-to-materials layer using the same modeling concepts, switching using layers-conversion coefficients like the _material intensities_ in this example. For instance population-to-service with per-capita service units coefficients, service-to-product using product usage coefficients (e.g. vehicle-km), materials-to-elements, and so on.
#
# 1. If more than one material in a product is to be modeled, each material should get its own materials-layer dynamic MFA system.
#
# 1. In cases in which material intensities do not change over time and are not expected to change, the conversion from the products layer to the materials layer can be reduced to simply multiplying all product-layer flows and stocks by the fixed-valued material intensity coefficient.
#
# 1. In this model, the material is assumed to last as long as the product it's in, and therefore both layers use the same survival curve. Modifying it to use separate survival behavior for the materials layer (e.g. periodic replacement of components during the use period) is beyond the scope of this model.
#
# 1. Please also read the notes and other details of the notebooks listed in “Relations with other RAPID-MFA notebooks”
#
# ### The exogenous input variables used in this example
# All exogenous variables originate from [Fishman and Graedel 2019](https://doi.org/10.1038/s41893-019-0252-z)
#
# __Stocks:__ Historical data and nationwide future "central scenario", simplified and modified for this example.
#
# __Survival curve:__ Normal distribution, $mean=20$ from the study, $SD=(mean/2)$ modified for this example.
#
# __Material intensities:__ Offshore wind turbines in units of generation capacity (MW) and converted to mass of Neodymium.
#
# ### Relations with other RAPID-MFA notebooks
# - `RAPID-MFA-1: The flow driven model`: is used for the materials layer, and the materials layer must remain using the flow driven model, see note above.
# - `RAPID-MFA-2: The stock driven model`: is used for the products layer in this example, but can be swapped with a flow-driven model, see note above.
# - This daisy-chained model is the basis for further RAPID-MFA notebooks, such as material substitution, product substitution, and others.
#
# ### Version, licence, and how to cite
#
# Version 2026.7 - check the [RAPID MFA GitHub repository](https://github.com/TomerFishman/RAPID-MFA/) for changes, history, and updates.
#
# This code was created and is maintained by the [RAPID MFA development team](https://github.com/TomerFishman/RAPID-MFA/tree/master#contributors-and-acknowledgements).
#
# This notebook is <a href="https://creativecommons.org/licenses/by-nc/4.0"><img src="https://mirrors.creativecommons.org/presskit/buttons/88x31/png/by-nc.png" alt="CC-BY-NC" width="70"> CC-BY-NC</a>, meaning you can - and should! - freely reuse and adapt this code for noncommercial purposes __as long as you attribute this source__.

# %% [markdown]
# ## 1. Load libraries

# %%
# %% 1. Load libraries
import numpy as np
import pandas as pd
import scipy.stats
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Define example input data

# %%
# %% 2. Define example input data

input_data = pd.Series([0, 30, 30, 30, 30, 30, 2985, 6523, 8721,
                        10171, 11851, 13772, 15729, 17621, 19480, 21761, 24793, 27959,
                        30680, 33460, 36803, 40144, 42956, 45948, 49759, 53522, 56405,
                        59223, 62825, 66555, 69664, 72539, 75776, 75776, 75000, 74234],
                        name = 'stocks', 
                        index = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 
                                 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 
                                 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 
                                 2045, 2046, 2047, 2048, 2049, 2050]) # megawatts installed capacity of wind turbines

# survival curve parameters inputs and creation of the survival function
ages = range(0, len(input_data)) # the maximum age in the MFA model is equal to the length of the input data
mean = 20  # offshore turbines have a mean lifespan of 20 years (Fishman and Graedel 2019)
std_dev = 10  # for this example, changed from sd = 5 in Fishman and Graedel 2019.
survival_curve = scipy.stats.norm.sf(ages, loc=mean, scale=std_dev)

# material Intensites (MIs)
mi_Nd_high = 175.5  # material intensity of kg of Neodymium per MW in 2015.
mi_Nd_low  = 124    # material intensity of kg of Neodymium per MW in 2050.

# Linear interpolation of MIs over time, describing an assumed technological efficiency improvement from 2025 to 2050
mi_Nd = pd.Series(np.nan, index=input_data.index.union([2015, 2025, 2050]), name='mi')
mi_Nd.loc[2015] = mi_Nd_high
mi_Nd.loc[2025] = mi_Nd_high
mi_Nd.loc[2050] = mi_Nd_low
mi_Nd = mi_Nd.sort_index().interpolate(method='index').ffill().bfill()
mi_Nd = mi_Nd.loc[input_data.index]

# %% [markdown]
# ## 3. Set up the MFA systems
#
# Set up two MFA systems, one for each of the two layers of products and materials, because they use different units of measurement.

# %%
# %% 3. Set up MFA systems for the two layers of products and materials
units = {'time_interval':   'year', 
         'flows_products':  'MW/year', 
         'stocks_products': 'MW', 
         'flows_materials': 'Nd/year', 
         'stocks_materials':'Nd'}

timeframes = cohorts = input_data.index  # timeframes are the "snapshots" of the system in every time interval, while cohorts are the inflows that enter the system in every time interval. They are the same because there is one inflow per time interval.

time_interval = 1 # Interval between timeframes, usually 1, e.g. from 2005 to 2006

cohort_stop = (cohorts[-1] + time_interval) #because of exclusive slicing in python, an extra time step needs to be added

mfa_system_products = pd.DataFrame(index = timeframes, columns = ['stocks',
                                                                  'inflows', 
                                                                  'outflows',
                                                                  'stock_changes'])

mfa_system_materials = pd.DataFrame(index = timeframes, columns = ['stocks',
                                                                   'inflows', 
                                                                   'outflows',
                                                                   'stock_changes'])

mfa_system_products['stocks'] = input_data

# %% [markdown]
# ## 4. Create the survival curves matrix
#
# In this example, the material (Nd) lasts as long as the product/service it's in (turbines in MW of energy generation) so the two layers share one survival curves matrix.

# %%
# %% 4. Create survival curves matrix
# create survival curve matrix filled with zeros
survival_curves_matrix = pd.DataFrame(0, index=timeframes, columns=cohorts, dtype=float)

# and populate that matrix
for cohort in cohorts:
    # at each iteration, the survival curve is shifted and the survival curve matrix is filled with the shifted survival curve
    survival_curves_matrix.loc[cohort: , cohort] = survival_curve[0 : cohort_stop - cohort]

# %% [markdown]
# ## 5. Calculate the MFA system of the products layer
#
# In this example the stocks of the product (turbines in MW of energy generation) is given so this step is a stock-driven model, but can be replaced with a flow-driven model if inflows are the exogenous input data.

# %%
# %% 5. Calculate the MFA system of the products layer

# Create cohorts survival matrix and calculate the inflows
# initialize the cohort_survival_matrix filled with zeros
cohorts_survival_matrix_products = pd.DataFrame(0, index=timeframes, columns=cohorts, dtype=float)

# And populate it while creating each inflow
for cohort in cohorts:
    # calculate the inflow of the time-th year
    mfa_system_products.loc[cohort, 'inflows'] = (
        mfa_system_products.loc[cohort, 'stocks'] - cohorts_survival_matrix_products.loc[cohort, : cohort - 1].sum()
    ) / survival_curves_matrix.loc[cohort, cohort]
    # now that the time-th inflow is known, scale the shifted survival curve with this inflow
    cohorts_survival_matrix_products.loc[:, cohort] = survival_curves_matrix.loc[:, cohort] * mfa_system_products.loc[cohort, 'inflows']

# calculate stock changes (net change to stock)
# prepend=0 replicates the convention that stock_change is the difference between current timeframe and previous timeframe. 
mfa_system_products["stock_changes"] = np.diff(mfa_system_products["stocks"], prepend=0)

# Calculate outflows using mass balance
mfa_system_products["outflows"] = mfa_system_products["inflows"] - mfa_system_products["stock_changes"]

# %% [markdown]
# ### View the full MFA system of the products layer

# %%
# %% View the full MFA system of the products layer
# plot flows of products

fig, axes = plt.subplots(1, 2, figsize=(9, 3))

mfa_system_products[["inflows", "outflows", "stock_changes"]].plot(
    ax=axes[0], ylabel=units['flows_materials'], title="Flows")
axes[0].axhline(0, color='black', linewidth=0.8)
axes[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

(mfa_system_products["stocks"]).plot(
    kind="area", stacked=True, ax=axes[1], ylabel=units['stocks_materials'], title="Stocks")
axes[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=1)

plt.tight_layout()

# %% [markdown]
# ## 6. Convert inflows from products to materials
# Using the material intensities time series:
# $
# \textcolor{#2A8596}{\text{material inflows}(t)[mass]} = \textcolor{#C58D01}{\text{product inflows}(t)[units]} \times \textcolor{#C32D2E}{\text{material intensities}(t)[\frac{mass}{unit}]}
# $

# %%
# %% 6. Convert inflows from products to materials
# material inflows(t) = product inflows(t) x material intensities(t)

mfa_system_materials['inflows'] = mfa_system_products['inflows'] * mi_Nd

# %% [markdown]
# ## 7. Calculate the MFA system of the materials layer
#
# Using a flow-driven MFA, because the inflows (in mass) are now available.

# %%
# %% 7. Calculate the MFA system of the materials layer
# Using a flow-driven MFA, because the inflows (in mass) are now available.

# Create cohorts survival matrix
# initialize the cohort_survival_matrix filled with zeros
cohorts_survival_matrix_materials = pd.DataFrame(0, index=timeframes, columns=cohorts, dtype=float)
# And populate it
for cohort in cohorts:
    # scale the shifted survival curve with the inflow of the time-th timeframe
    cohorts_survival_matrix_materials.loc[:, cohort] = survival_curves_matrix.loc[:, cohort] * mfa_system_materials['inflows'].loc[cohort]

# the stocks are the sum of the surviving cohorts, which is the sum of cohorts survival matrix row by row.
mfa_system_materials["stocks"] = cohorts_survival_matrix_materials.sum(axis='columns')

# calculate stock changes (net change to stock)
# prepend=0 replicates the convention that stock_change is the difference between current timeframe and previous timeframe. 
mfa_system_materials["stock_changes"] = np.diff(mfa_system_materials["stocks"], prepend=0)

# Calculate outflows using mass balance
mfa_system_materials["outflows"] = mfa_system_materials["inflows"] - mfa_system_materials["stock_changes"]

# %% [markdown]
# ### View the full MFA system of the materials layer
#
# Compared with the equivalent plot of the products layer, not only have the units of measurement changed, __the trends are different__: inflows are flatter, stock changes start declining, etc.

# %%
# %% View the full MFA system of the materials layer
# plot flows of materials
fig, axes = plt.subplots(1, 2, figsize=(9, 3))

mfa_system_materials[["inflows", "outflows", "stock_changes"]].plot(
    ax=axes[0], ylabel=units['flows_materials'], title="Flows")
axes[0].axhline(0, color='black', linewidth=0.8)
axes[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

(mfa_system_materials["stocks"]/1e6).plot(
    kind="area", stacked=True, ax=axes[1], ylabel='Million kg ' + units['stocks_materials'], title="Stocks")
axes[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=1)

plt.tight_layout()

# %% [markdown]
# ### Material stock productivity
#
# $\text{Material stock productivity} = \frac{\text{service provision}}{\text{material stock}}$

# %%
(mfa_system_products["stocks"] / mfa_system_materials["stocks"]).plot(ylim=(0,0.01), ylabel="material stock productivity [MW/Nd]");
