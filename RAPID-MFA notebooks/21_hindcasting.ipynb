# %% [markdown]
# # RAPID-MFA-21: Hindcasting
#
# ## Descriptions
#
# Hindcasting recreates past inflows for which data is not available. It traces the cohorts within a given stock back in time to their original inflows.

# %% [markdown]
# <svg width="616" height="344" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" overflow="hidden">
#   <defs>
#     <clipPath id="clip0">
#       <rect x="0" y="0" width="616" height="344" />
#     </clipPath>
#   </defs>
#   <g clip-path="url(#clip0)">
#     <rect x="0" y="0" width="616" height="344" fill="#FFFFFF" />
#     <path d="M155 309 612.864 309" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M80 96C118.592 101.88 157.184 107.76 194.31 135.02 231.437 162.281 262.31 231.235 302.759 259.565 343.207 287.895 390.103 296.448 437 305" stroke="#722299" stroke-width="8" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M162 104C200.592 109.683 239.184 115.366 276.31 141.714 313.437 168.061 344.31 234.706 384.759 262.087 425.207 289.468 472.103 297.734 519 306" stroke="#D19F37" stroke-width="8" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M243 87C281.592 93.133 320.184 99.266 357.31 127.701 394.437 156.136 425.31 228.059 465.759 257.609 506.207 287.159 553.103 296.079 600 305" stroke="#DC322F" stroke-width="8" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M15 121C53.7 126.176 92.4001 131.353 129.631 155.353 166.861 179.353 197.821 240.059 238.383 265 278.944 289.941 325.972 297.471 373 305" stroke="#2A8596" stroke-width="8" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M13 55 13.0001 309.137" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(188.107 22.5)">known current</text>
#     <path d="M13 309 400.145 309" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(134.355 81)">hindcasting</text>
#     <path d="M0 4.49999 10 4.49999 10 0 19 8.99999 10 18 10 13.5 0 13.5Z" fill="#2F2B20" fill-rule="evenodd" transform="matrix(-1 0 0 1 131 67)" />
#     <path d="M69 95.5C69 89.701 73.701 85 79.5 85 85.299 85 90 89.701 90 95.5 90 101.299 85.299 106 79.5 106 73.701 106 69 101.299 69 95.5Z" stroke="#722299" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M4 121C4 114.925 8.70101 110 14.5 110 20.299 110 25 114.925 25 121 25 127.075 20.299 132 14.5 132 8.70101 132 4 127.075 4 121Z" stroke="#2A8596" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M151 103.5C151 97.701 155.701 93 161.5 93 167.299 93 172 97.701 172 103.5 172 109.299 167.299 114 161.5 114 155.701 114 151 109.299 151 103.5Z" stroke="#D19F37" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M243 305 243 314.844" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M166 309 166 318.844" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M13 309 13.0001 318.844" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <path d="M90 309 90.0001 318.844" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(239.98 335)">t</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(155.963 335)">t-1</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(78.3925 335)">t-2</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(2.22824 335)">t-3</text>
#     <path d="M314 309 314 318.844" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#A6A6A6" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(300.554 335)">t+1</text>
#     <path d="M384 309 384 318.844" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#A6A6A6" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(371.084 335)">t+2</text>
#     <rect x="243" y="72" width="369" height="237" fill="#FFFFFF" fill-opacity="0.7" />
#     <text fill="#A6A6A6" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(287.09 81)">forecasting</text>
#     <path d="M381 71.5 391 71.5 391 67 400 76 391 85 391 80.5 381 80.5Z" fill="#A6A6A6" fill-rule="evenodd" />
#     <path d="M450 58.5C450 54.3579 453.358 51 457.5 51 461.642 51 465 54.3579 465 58.5 465 62.6421 461.642 66 457.5 66 453.358 66 450 62.6421 450 58.5Z" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="#2F2B20" fill-rule="evenodd" />
#     <path d="M450 130.5C450 126.358 453.358 123 457.5 123 461.642 123 465 126.358 465 130.5 465 134.642 461.642 138 457.5 138 453.358 138 450 134.642 450 130.5Z" stroke="#2F2B20" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(470.353 40)">Cohort’s known</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(470.353 63)">current remaining</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(470.353 85)">amount and age</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(471.799 126)">Hindcasted initial</text>
#     <text fill="#2F2B20" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(471.799 149)">amount of cohort</text>
#     <text fill="#2A8596" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="700" font-size="18.6667" transform="translate(259.461 270)">c-3</text>
#     <text fill="#722299" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="700" font-size="18.6667" transform="translate(259.461 193)">c-2</text>
#     <text fill="#D19F37" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="700" font-size="18.6667" transform="translate(259.461 124)">c-1</text>
#     <text fill="#DC322F" font-family="Aptos,Aptos_MSFontService,sans-serif" font-weight="700" font-size="18.6667" transform="translate(259.461 78)">c</text>
#     <path d="M234.5 88.0001C234.5 83.3056 238.306 79.5001 243 79.5001 247.694 79.5001 251.5 83.3056 251.5 88.0001 251.5 92.6945 247.694 96.5001 243 96.5001 238.306 96.5001 234.5 92.6945 234.5 88.0001Z" stroke="#FFFFFF" stroke-width="0.666667" stroke-miterlimit="8" fill="#DC322F" fill-rule="evenodd" />
#     <path d="M234 124.5C234 119.806 238.029 116 243 116 247.971 116 252 119.806 252 124.5 252 129.194 247.971 133 243 133 238.029 133 234 129.194 234 124.5Z" stroke="#D19F37" stroke-width="2" stroke-miterlimit="8" fill="#D19F37" fill-rule="evenodd" />
#     <path d="M234 191.5C234 186.806 238.029 183 243 183 247.971 183 252 186.806 252 191.5 252 196.194 247.971 200 243 200 238.029 200 234 196.194 234 191.5Z" stroke="#722299" stroke-width="2" stroke-miterlimit="8" fill="#722299" fill-rule="evenodd" />
#     <path d="M234 268.5C234 263.806 238.029 260 243 260 247.971 260 252 263.806 252 268.5 252 273.194 247.971 277 243 277 238.029 277 234 273.194 234 268.5Z" stroke="#2A8596" stroke-width="2" stroke-miterlimit="8" fill="#2A8596" fill-rule="evenodd" />
#     <path d="M0 0 0.000104987 255.073" stroke="#A6A6A6" stroke-width="1.33333" stroke-miterlimit="8" stroke-dasharray="5.33333 4" fill="none" fill-rule="evenodd" transform="matrix(1 0 0 -1 243.5 305.574)" />
#     <path d="M232 87.5C232 81.701 236.925 77 243 77 249.075 77 254 81.701 254 87.5 254 93.299 249.075 98 243 98 236.925 98 232 93.299 232 87.5Z" stroke="#DC322F" stroke-width="2" stroke-miterlimit="8" fill="none" fill-rule="evenodd" />
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(125.673 41)">𝑠𝑡𝑜𝑐𝑘𝑠</text>
#     <path d="M195.845 27.0874C197.62 27.5553 198.982 28.5655 199.933 30.118 200.884 31.6705 201.36 33.5436 201.36 35.7372 201.36 37.9368 200.886 39.8099 199.938 41.3563 198.99 42.9028 197.626 43.9099 195.845 44.3778L195.627 43.676C197.03 43.2081 198.074 42.2845 198.757 40.9051 199.441 39.5258 199.783 37.7728 199.783 35.646 199.783 33.5922 199.443 31.8863 198.762 30.5282 198.081 29.1701 197.027 28.2571 195.599 27.7893ZM186.874 27.0874 187.121 27.7893C185.699 28.2571 184.646 29.1701 183.962 30.5282 183.279 31.8863 182.937 33.5922 182.937 35.646 182.937 37.7728 183.279 39.5258 183.962 40.9051 184.646 42.2845 185.69 43.2081 187.093 43.676L186.874 44.3778C185.094 43.9099 183.73 42.9028 182.782 41.3563 181.834 39.8099 181.36 37.9368 181.36 35.7372 181.36 33.5436 181.836 31.6705 182.787 30.118 183.738 28.5655 185.1 27.5553 186.874 27.0874Z" fill="#2F2B20" fill-rule="evenodd" />
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(187.466 41)">𝑡</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(208.186 41)">=</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(224.78 41)"></text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(231.54 41)">Σ</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="13.6267" transform="translate(241.706 45)">𝑐</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="13.6267" transform="translate(248.973 45)">=</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="13.6267" transform="translate(258.806 45)">𝑡</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="11.2" transform="translate(264.806 48)">0</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="13.6267" transform="translate(242.3 34)">𝑡</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(272.813 41)">𝑐𝑜ℎ𝑜𝑟𝑡𝑠</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(337.026 41)">(</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(344.693 41)">𝑐</text>
#     <text fill="#2F2B20" font-family="Cambria Math,Cambria Math_MSFontService,sans-serif" font-weight="400" font-size="18.6667" transform="translate(353.953 41)">)</text>
#     <rect x="116.5" y="8.50005" width="254" height="44" stroke="#A6A6A6" stroke-width="1.33333" stroke-miterlimit="8" stroke-dasharray="5.33333 4" fill="none" />
#   </g>
# </svg>

# %% [markdown]
# This notebook generalizes the hindcasting model of [Böcher et al., 2025](https://doi.org/10.1016/j.resconrec.2025.108198).
#
# The hindcasting model takes three inputs:
# - A _current stocks_ in a single timeframe with its cohorts' age composition (e.g. current stocks' cohorts by construction year)
# - A _survival curve_ describing the survival/depreciation of inflow cohorts in the stocks as time goes/went by
# - The _switchpoint_ timeframe in which the lifetime changes from the old to the new survival curve.
#
#
# And produces one main output:
# - The _inflows_ time series
#
# Which in turn feed into a _flow driven model_ that produces two main model outputs:
#
# - The _stocks_ time series
# - The _outflows_ time series
#
# And two auxiliary model outputs:
# - The _cohorts survival matrix_ table
# - The _stock changes_ (net addition to stock) time series
#
#
#
#
# ### Hindcasting the historical inflows
#
# The hindcasting model starts from a stock in a single timeframe $t$ that has a known cohorts composition:
#
# $
# \textcolor{#DC322F}{\text{stocks}(t)} = \sum_{c=t_0}^{t} \text{cohorts}(c)
# $
#
# This is equivalent to a given _row_ $t$ in a dynamic MFA's _cohorts survival matrix_. Reminder: the core flow-driven model creates rows in the _cohorts survival matrix_ uses the equation:
#
# $
# \textcolor{#DC322F}{\text{stocks}(t)} = \sum_{c=t_0}^{t}{ [ \textcolor{#2A8596}{\text{inflows}(c)} \times \textcolor{#722299}{\text{survival\_curve}(t-c)}  ] }
# $
#
# Combining these two equations, each of the stock’s cohorts is equal to the still-surviving inflow from a past timeframe:
#
# $\text{cohorts}(c) = \textcolor{#2A8596}{\text{inflows}(c)} \times \textcolor{#722299}{\text{survival\_curve}(t-c)}$
#
# Which enables the calculation of the original value of each inflow that created each cohort:
#
# $\textcolor{#2A8596}{\text{inflows}(c)} = \frac{\text{cohorts}(c)}{\textcolor{#722299}{\text{survival\_curve}(t-c)}}$
#
# This results in a full $\text{inflows}$ time series from the oldest cohort $c$ to the existing stock's timeframe $t$. This inflow can then be used in a _flow driven dynamic MFA_ model to fill in the entire MFA system of historical stocks and flows.
#
# ### Notes
# 1. Hindcasting does **not** necessarily assume that all cohorts have the same survival curve, as exemplified below.
# 1. Please also read the notes and other details of the notebooks listed in “Relations with other RAPID-MFA notebooks”
#
#
# ### The exogenous input variables used in this example
#
# The example uses the 2019 stock with its constituent cohorts' age composition from the `RAPID-MFA-1: The flow driven model` (or equally from `RAPID-MFA-2: The stock driven model` as their data are identical).
#
# However, for the sake of the exemplifying note 1, The post-1990 cohorts are assumed to originate from inflows with a different survival curve than the pre-1990 building cohorts. This means that the recreated hindcasted inflows will not be identical to the input inflows data from `RAPID-MFA-1: The flow driven model`.
#
# __known stocks:__  the stock in the year 2019, classified by its cohorts' inflow years. From the model outputs of `RAPID-MFA-1: The flow driven model`.
#
# __survival curve old:__ mock values, normal distribution, $mean=30$, $SD=8.5$.
#
# __survival curve post new:__ mock values, Weibull distribution, $shape = 5.679$, $scale = 32$.
#
# ### Relations with other RAPID-MFA notebooks
# - `RAPID-MFA-1: The flow driven model`: the basic flow driven model is used to calculate the entire MFA system, once the hindcasted inflows get calculated. The _survival curve pre-1990_ is identical, and the _known stocks_ are from the model's data outputs.
# - `RAPID-MFA-5: A library of survival curves`: The _post-`1990 survival curve_'s parameters are from the Weibull distribution example.
# - `RAPID-MFA-6: Varying lifetimes`: though not a requirement for hindcasting, in this example some cohorts' original inflows have different survival curves. See `RAPID-MFA-6: Varying lifetimes` for further examples of varying survival curves and how they change the core dynamic MFA model.
#
# ### Version, licence, and how to cite
#
# Version 2026.7 - check the [RAPID MFA GitHub repository](https://github.com/TomerFishman/RAPID-MFA/) for changes, history, and updates.
#
# This code was created and is maintained by the [RAPID MFA development team](https://github.com/TomerFishman/RAPID-MFA/tree/master#contributors-and-acknowledgements).
#
# This notebook is <a href="https://creativecommons.org/licenses/by-nc/4.0"><img src="https://mirrors.creativecommons.org/presskit/buttons/88x31/png/by-nc.png" alt="CC-BY-NC" width="70"> CC-BY-NC</a>, meaning you can - and should! - freely reuse and adapt this code for noncommercial purposes __as long as you attribute this source__.

# %% [markdown]
# ## 1. Load libraries

# %%
# %% 1. Load libraries
import numpy as np
import pandas as pd
import scipy.stats
import math
import seaborn as sns

# %% [markdown]
# ## 2. Define example input data
#
# In this example, *known_stocks* is the composition of the 2022 building stock, so the index of this data is the year of construction of each cohort. The pre-1945 buildings cohorts are assumed to originate from inflows with a different survival curve than the post-1945 building cohorts.

# %%
# %% 2. Define example input data

# the known stock's composition by cohorts
known_stocks = pd.Series([0.0029055562109335195, 0.005460332733590248, 0.008059392037386039, 0.011412637535617831, 0.013396609922825695,
                          0.06334248366623972, 0.11379563763836728, 0.19175701825869848, 0.3713629011026993, 0.6247268416848634,
                          0.45180660083222746, 0.641752576898014, 1.4907890540129831, 2.444288015276047, 4.904523019040521,
                          3.5623550769140877, 10.21847627987542, 15.917394884546319, 18.884745219238766, 27.00709141673415,
                          19.04853449965237, 46.17670893121078, 68.25039584453758, 95.66097732234272, 128.06179560520894,
                          169.22812452752717, 227.0923159364674, 260.73176884820816, 371.68709505160643, 466.8434136537392,
                          477.9722569622322, 693.2288650061012, 902.4553971229707, 1200.6532568835573, 1418.754644588612,
                          1658.6305075364883, 1955.1578590500815, 2360.543335209062, 2809.676680474798, 3000.0,
                          3280.9580511534205, 3558.058618749246, 3955.1891247943513, 5243.9509792248155, 4330.876888719279,
                          4179.2814174280875, 4530.910053727061, 4794.818145741154, 5045.443540582675, 5281.779363609632,
                          5593.563160705274, 6078.536462303583, 5996.280327224058, 6176.47564428561, 6728.353766898042,
                          6305.688639813991, 6449.849129142017, 6585.41335191144, 6911.106839001623, 7628.291515893498,
                          5760.88159918872, 5871.54162732763, 5979.56304744025, 5985.750579692343, 6189.8639857606495,
                          7691.444991946534, 5995.527632837961, 5497.284892943893, 5698.160501696611, 6698.604776720237],
                          name = 'remaining cohorts amounts',
                          index = [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 
                                   1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 
                                   1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 
                                   1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 
                                   1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 
                                   2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 
                                   2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])


# Timeframe of the change of the survival curves
switchpoint_timeframe = 1990 

# The timeframe of this stock (i.e. the last and newest cohort)
known_stocks_timeframe = known_stocks.index[-1]

# Parameters and creation of the survival curves
ages = range(0, len(known_stocks))  # the maximum age in the MFA model is equal to the length of the input data

mean = 30
std_dev = 8.5
survival_curve_old = scipy.stats.norm.sf(ages, loc=mean, scale=std_dev)

shape = 5.679
location = 0
scale = 32
survival_curve_new = scipy.stats.weibull_min.sf(ages, c = shape, loc = location, scale = scale)

# Interval between timeframes, often 1 year or 1 month etc.
time_interval = 1

# %% [markdown]
# The _known stock_ can be visualized as an age pyramid, with each of its constituent _cohorts_ as a bar.

# %%
known_stocks.plot(kind="barh", width=1, 
                  xlabel="remaining cohorts amounts", ylabel="cohorts", 
                  title=str(known_stocks_timeframe) + " stock age pyramid", figsize=(5, 5),
                  ).set(yticks=np.arange(0, len(known_stocks), 5));

# %% [markdown]
# ## 3. Set up the MFA system
#
# This code cell is identical to the core MFA models, except that the time variables _timeframes_ and _cohorts_ are defined by the number (and timeframes) of the cohorts composing the _known stock_.
#
# In other words, the time period that this MFA system will cover is from the inflow of the earliest cohort in the stock (in this example 1950) until the inflow of the timeframe of the known stock (in this example 2019).

# %%
# %% 3. Set up the MFA system
units = {'time_interval': 'year', 
         'flows':         'number of buildings/year', 
         'stocks':        'number of buildings'}

timeframes = cohorts = known_stocks.index  # timeframes are the "snapshots" of the system in every time interval, while cohorts are the inflows that enter the system in every time interval. They are the same because we have one inflow per time interval.

cohort_stop = (cohorts[-1] + time_interval)  # because of exclusive slicing in python, an extra time interval is required

mfa_system = pd.DataFrame(index = timeframes, columns = ['stocks',
                                                         'inflows', 
                                                         'outflows', 
                                                         'stock_changes'])

# %% [markdown]
# ## 4. Create the survival curves matrix
#
# In this example, pre-1990 cohorts have a different survival curve than post-1990 cohorts, so this code cell is more similar to `RAPID-MFA-6: Varying lifetimes`. If all cohorts have the same survival curve, then the regular code from the core models can be used.

# %%
# %% 4. Create survival curves matrix
# create survival curve matrix filled with zeros
survival_curves_matrix = pd.DataFrame(0, index=timeframes, columns=cohorts, dtype=float)

switchpoint_index = switchpoint_timeframe - cohorts[0]
for cohort in cohorts[0 : switchpoint_index]:
   survival_curves_matrix.loc[cohort: , cohort] = survival_curve_old[0 : cohort_stop - cohort]
for cohort in cohorts[switchpoint_index : ]:
    survival_curves_matrix.loc[cohort: , cohort] = survival_curve_new[0 : cohort_stop - cohort]

    # and visualize the survival_curves_matrix matrix with a heatmap
sns.heatmap(survival_curves_matrix, annot=False).set(xlabel ="Cohorts", ylabel = "Timeframe");

# %% [markdown]
# ## 5. Hindcasting past inflows
#
# $\text{inflows}(c) = \frac{\text{cohorts}(c)}{\text{survival\_curve}(t - c)}$

# %%
for cohort in cohorts:
    mfa_system.loc[cohort, "inflows"] = known_stocks[cohort] / survival_curves_matrix.loc[known_stocks_timeframe, cohort]

# %% [markdown]
# ## 6. Run the flow-driven model
#
# Now that the historical inflows are known, this code cell is identical to `RAPID-MFA-1: The flow driven model`

# %%
# %% Create cohorts survival matrix

# initialize the cohort_survival_matrix filled with zeros
cohorts_survival_matrix = pd.DataFrame(0, index=timeframes, columns=cohorts, dtype=float)

# And populate it
for cohort in cohorts:
    # scale the shifted survival curve with the inflow of the time-th timeframe
    cohorts_survival_matrix.loc[:, cohort] = survival_curves_matrix.loc[:, cohort] * mfa_system['inflows'].loc[cohort]

# %% Calculate the MFA system
# %%% Calculate stocks 
# the stocks are the sum of the surviving cohorts, which is the sum of cohorts survival matrix row by row.
mfa_system["stocks"] = cohorts_survival_matrix.sum(axis='columns')

# %%% calculate stock changes (net change to stock)
# stock_changes is the difference between two timeframes.
# prepend=0 replicates the convention that stock_change is the difference between current timeframe and previous timeframe. 
mfa_system["stock_changes"] = np.diff(mfa_system["stocks"], prepend=0)

# %%% Calculate outflows
# using mass balance
mfa_system["outflows"] = mfa_system["inflows"] - mfa_system["stock_changes"]

# %% [markdown]
# ## 7. Diagnostics
# The flow-driven model is "blind" to the fact that its inflows were hindcasted.
#
# Simple comparisons can therefore confirm that the flow-driven model manages to accurately recreate the "known stock" and its composition:

# %%
# the total known stock is the sum of its cohorts
known_stocks_total = known_stocks.sum()

# compare the total stock of the last timeframe to the originally known stock
mfa_system.loc[known_stocks_timeframe, "stocks"] == known_stocks_total;

# %%
# compare each cohort of the last timeframe to the originally known stock's cohorts
cohorts_survival_matrix.loc[known_stocks_timeframe, :] == known_stocks;

# %% [markdown]
# ## 8. View the full MFA system
#
# This MFA system is identical to the one from `RAPID-MFA-1: The flow driven model` until 1990 because both use the same survival curve. From 1991 onward this system diverges because it uses a different survival curve for the post-1990 inflow cohorts.

# %%
# %% View the full MFA system

# plot flows
mfa_system[["inflows", "outflows", "stock_changes"]].plot(ylabel=units['flows']);

# %%
# plot stocks
mfa_system["stocks"].plot(kind="area", stacked=True, ylabel=units['stocks'])
# Out:
# <Axes: ylabel='number of buildings'>
